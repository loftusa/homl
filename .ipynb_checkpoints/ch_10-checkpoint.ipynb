# %% [markdown]
# # Introduction to Artificial Neural Networks with Keras

# %% [markdown]
# ## Make training data

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import Normalize

# %%
dim = (8, 8)
stacknum = 5

zeros = np.zeros(dim)
whites = zeros + np.abs(np.random.randn(5, *dim)) * (np.arange(1, stacknum+1)*.1)[:, None, None]
fig, axs = plt.subplots(1, 5, figsize=(25, 5))
for i, ax in enumerate(axs.flat):
    ax.imshow(whites[i], cmap="Greys", vmin=0, vmax=1)
    
norm = Normalize(vmin=0, vmax=1)
im = cm.ScalarMappable(cmap="Greys", norm=norm)
fig.colorbar(im, ax=axs);

# %%
dim = (8, 8)
stacknum = 5

ones = np.ones(dim)
blacks = ones - np.abs(np.random.randn(5, *dim)) * (np.arange(1, stacknum+1)*.1)[:, None, None]
fig, axs = plt.subplots(1, 5, figsize=(25, 5))
for i, ax in enumerate(axs.flat):
    ax.imshow(blacks[i], cmap="Greys", vmin=0, vmax=1)
    
norm = Normalize(vmin=0, vmax=1)
im = cm.ScalarMappable(cmap="Greys", norm=norm)
fig.colorbar(im, ax=axs);

# %% [markdown]
# ### Get data

# %%
import tensorflow as tf
from tensorflow import keras

from keras.datasets.fashion_mnist import load_data
(X_train_full, y_train_full), (X_test, y_test) = load_data()

# get validation set
X_valid, y_valid = X_train_full[:5000]/255.0, y_train_full[:5000]
X_train, y_train = X_train_full[5000:]/255.0, y_train_full[5000:]
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", 
               "Sneaker", "Bag", "Ankle boot"]

y_names_train = [class_names[i] for i in y_train]

# %% [markdown]
# ### Train model

# %%
model = keras.models.Sequential([
keras.layers.Flatten(input_shape=X_valid[0].shape),
keras.layers.Dense(300, activation='relu'),
keras.layers.Dense(100, activation='relu'),
keras.layers.Dense(10, activation='softmax'),
                                ])


weights, biases = model.layers[1].get_weights()

model.compile(loss='sparse_categorical_crossentropy', optimizer="sgd", metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=30, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/30
# 1719/1719 [==============================] - 2s 931us/step - loss: 0.9876 - accuracy: 0.6868 - val_loss: 0.4989 - val_accuracy: 0.8304
# Epoch 2/30
# 1719/1719 [==============================] - 1s 863us/step - loss: 0.5006 - accuracy: 0.8259 - val_loss: 0.4387 - val_accuracy: 0.8490
# Epoch 3/30
# 1719/1719 [==============================] - 2s 883us/step - loss: 0.4501 - accuracy: 0.8440 - val_loss: 0.4028 - val_accuracy: 0.8600
# Epoch 4/30
# 1719/1719 [==============================] - 2s 892us/step - loss: 0.4187 - accuracy: 0.8558 - val_loss: 0.4076 - val_accuracy: 0.8628
# Epoch 5/30
# 1719/1719 [==============================] - 1s 868us/step - loss: 0.3977 - accuracy: 0.8600 - val_loss: 0.3919 - val_accuracy: 0.8660
# 1719/1719 [==============================] - 1s 869us/step - loss: 0.2599 - accuracy: 0.9063 - val_loss: 0.3035 - val_accuracy: 0.8924
# Epoch 23/30
# 1719/1719 [==============================] - 2s 874us/step - loss: 0.2503 - accuracy: 0.9081 - val_loss: 0.3112 - val_accuracy: 0.8918
# Epoch 24/30
# 1719/1719 [==============================] - 2s 914us/step - loss: 0.2561 - accuracy: 0.9079 - val_loss: 0.3101 - val_accuracy: 0.8906
# Epoch 25/30
# 1719/1719 [==============================] - 1s 870us/step - loss: 0.2403 - accuracy: 0.9140 - val_loss: 0.3087 - val_accuracy: 0.8886
# Epoch 26/30
# 1719/1719 [==============================] - 1s 869us/step - loss: 0.2392 - accuracy: 0.9133 - val_loss: 0.2967 - val_accuracy: 0.8886
# Epoch 27/30
# 1719/1719 [==============================] - 2s 879us/step - loss: 0.2370 - accuracy: 0.9158 - val_loss: 0.3128 - val_accuracy: 0.8918
# Epoch 28/30
# 1719/1719 [==============================] - 1s 866us/step - loss: 0.2350 - accuracy: 0.9163 - val_loss: 0.2957 - val_accuracy: 0.8952
# Epoch 29/30
# 1719/1719 [==============================] - 2s 876us/step - loss: 0.2313 - accuracy: 0.9171 - val_loss: 0.3061 - val_accuracy: 0.8914
# Epoch 30/30
# 1719/1719 [==============================] - 2s 908us/step - loss: 0.2263 - accuracy: 0.9176 - val_loss: 0.3085 - val_accuracy: 0.8902

# %%
import pandas as pd

pd.DataFrame(history.history).plot(figsize=(15, 7))
# Out:
# <AxesSubplot:>

# %%
to_pred = X_test[:3]

prediction = model.predict(to_pred)
vals = np.argmax(prediction, axis=1)

[class_names[val] for val in vals]
# Out:
# ['Ankle boot', 'Pullover', 'Trouser']

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

for i, ax in enumerate(axs.flat):
    ax.imshow(to_pred[i], cmap="Greys")
    ax.set_title(class_names[vals[i]])

# %% [markdown]
# ## Regression MLP

# %% [markdown]
# Using california housing dataset

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

housing = fetch_california_housing()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-c6e38be9528e> in <module>
#       3 from sklearn.preprocessing import StandardScaler
#       4
# ----> 5 housing = fetch_california_housing()
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/sklearn/datasets/_california_housing.py in fetch_california_housing(data_home, download_if_missing, return_X_y, as_frame)
#     132             ARCHIVE.url, data_home))
#     133
# --> 134         archive_path = _fetch_remote(ARCHIVE, dirname=data_home)
#     135
#     136         with tarfile.open(mode="r:gz", name=archive_path) as f:
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/sklearn/datasets/_base.py in _fetch_remote(remote, dirname)
#    1187     file_path = (remote.filename if dirname is None
#    1188                  else join(dirname, remote.filename))
# -> 1189     urlretrieve(remote.url, file_path)
#    1190     checksum = _sha256(file_path)
#    1191     if remote.checksum != checksum:
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = _splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/urllib/request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/urllib/request.py in https_open(self, req)
#    1391
#    1392         def https_open(self, req):
# -> 1393             return self.do_open(http.client.HTTPSConnection, req,
#    1394                 context=self._context, check_hostname=self._check_hostname)
#    1395
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1348         try:
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#    1352             except OSError as err: # timeout error
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1253                 encode_chunked=False):
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#    1257     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1299             # default charset of iso-8859-1.
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#    1303     def getresponse(self):
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/http/client.py in endheaders(self, message_body, encode_chunked)
#    1248         else:
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#    1252     def request(self, method, url, body=None, headers={}, *,
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/http/client.py in _send_output(self, message_body, encode_chunked)
#    1008         msg = b"\r\n".join(self._buffer)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#    1012         if message_body is not None:
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/http/client.py in send(self, data)
#     948         if self.sock is None:
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#     952                 raise NotConnected()
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/http/client.py in connect(self)
#    1415             "Connect to a host on a given (SSL) port."
#    1416
# -> 1417             super().connect()
#    1418
#    1419             if self._tunnel_host:
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/http/client.py in connect(self)
#     919     def connect(self):
#     920         """Connect to the host and port specified in __init__."""
# --> 921         self.sock = self._create_connection(
#     922             (self.host,self.port), self.timeout, self.source_address)
#     923         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     794             if source_address:
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#     798             err = None
#
# KeyboardInterrupt:

# %%
housing
